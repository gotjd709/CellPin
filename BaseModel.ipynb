# %% [markdown]
# # BaseLine Code
#
# - 약 106개의 이미지만을 사용하여 만든 baseline code
#
# ## Step 1. 실험환경 set-up
#
# #### 라이브러리 실행

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %% [markdown]
# #### 필요한 변수들 생성

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# BATCH_SIZE 변수
BATCH_SIZE = 32

# 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 30

# %% [markdown]
# ## Step 2. 데이터 준비하기
#
# 먼저 아래의 링크에서 데이터를 다운 받을 것
#
# https://drive.google.com/drive/folders/1Pi5qyX080zY2IdGT1TvvLraBO9DHBxJl?usp=sharing
#
# 받은 후 터미널 창에 아래의 명령어들을 차례로 입력
#
# ```
# $ cd ~/Downloads && cp CellPin ~/aiffel
# ```
#
# #### 데이터의 개수 확인

# %%
# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel/CellPin')
print(ROOT_PATH)

train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# /home/aiffel-dj63/aiffel/CellPin
# 85
# 21
# 0

# %% [markdown]
# #### train과 validation을 80:20으로 분할

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/val/*/*')))

train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 68
# 17

# %% [markdown]
# #### train 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in train_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 44
# CPE images count in training set: 24

# %% [markdown]
# #### val 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in val_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in val_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 12
# CPE images count in training set: 5

# %% [markdown]
# #### test 데이터 안에 정상 이미지 수와 CPE 이미지 수

# %%
COUNT_NORMAL = len([filename for filename in test_filenames if "normal" in filename])
print("NORMAL images count in training set: " + str(COUNT_NORMAL))

COUNT_CPE = len([filename for filename in test_filenames if "cpe" in filename])
print("CPE images count in training set: " + str(COUNT_CPE))
# Out:
# NORMAL images count in training set: 13
# CPE images count in training set: 8

# %% [markdown]
# #### tf.data 인스턴스를 만들기

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %% [markdown]
# #### train data와 val data의 개수 확인

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 68
# Validating images count: 17

# %% [markdown]
# #### 라벨 이름들 확인

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/train/*"))])
print(CLASS_NAMES)
# Out:
# ['normal' 'cpe']

# %% [markdown]
# #### 라벨링 함수를 만들어 보기

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "cpe"

# %% [markdown]
# #### decode_img 함수와 process_path 함수를 만들기

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %% [markdown]
# #### train과 val에 함수들 적용해주기

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function get_label at 0x7f12fb4fe200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function get_label at 0x7f12fb4fe200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %% [markdown]
# #### 전처리 함수 만들기 및 적용

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# #### Image shape를 변경 체크하기

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (32, 180, 180, 3)
# Label:  [False False  True False  True False False  True  True False  True False
#  False  True  True False  True  True False False  True False False False
#  False False  True  True False  True False False]

# %% [markdown]
# #### test 데이터 셋도 만들어 보기 & 데이터의 갯수 확인

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 21

# %% [markdown]
# ## Step 3. 데이터 시각화
#
# #### 16개의 샘플 꺼내서 확인

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(4,4,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("CPE")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# #### Conv Block 함수 만들기

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %% [markdown]
# #### Dense Block 함수 만들기

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %% [markdown]
# #### model building

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## Step 5. 데이터 imbalance 처리
#
# #### 이 weight들은 'Normal'과 'Cpe' 전체 데이터 건수에 반비례하도록 설정

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_CPE)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 2.62
# Weight for class 1: 4.25

# %% [markdown]
# ## Step 6. 모델 훈련
#
# #### GPU사용하여 model complie

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %% [markdown]
# #### 모델 fitting

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=2,  # VAL_IMG_COUNT // BATCH_SIZE 
        class_weight=class_weight,
    )
# Out:
# Epoch 1/30
# 2/2 [==============================] - 33s 6s/step - loss: 3.0347 - accuracy: 0.5208 - precision: 0.3771 - recall: 0.4918 - val_loss: 0.6904 - val_accuracy: 0.7188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/30
# 2/2 [==============================] - 7s 6s/step - loss: 2.7671 - accuracy: 0.5312 - precision: 0.3873 - recall: 0.4855 - val_loss: 0.6860 - val_accuracy: 0.7188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/30
# 2/2 [==============================] - 6s 6s/step - loss: 3.0243 - accuracy: 0.4479 - precision: 0.3399 - recall: 0.4594 - val_loss: 0.6809 - val_accuracy: 0.7188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/30
# 2/2 [==============================] - 7s 7s/step - loss: 2.9712 - accuracy: 0.4271 - precision: 0.2685 - recall: 0.4545 - val_loss: 0.6773 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/30
# 2/2 [==============================] - 7s 7s/step - loss: 3.8574 - accuracy: 0.4271 - precision: 0.3148 - recall: 0.4855 - val_loss: 0.6710 - val_accuracy: 0.7188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/30
# 2/2 [==============================] - 7s 6s/step - loss: 2.9786 - accuracy: 0.5521 - precision: 0.4906 - recall: 0.5012 - val_loss: 0.6695 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/30
# 2/2 [==============================] - 7s 7s/step - loss: 2.7811 - accuracy: 0.5208 - precision: 0.3127 - recall: 0.6481 - val_loss: 0.6683 - val_accuracy: 0.6875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/30
# 2/2 [==============================] - 6s 6s/step - loss: 2.7799 - accuracy: 0.5208 - precision: 0.3953 - recall: 0.5991 - val_loss: 0.6628 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/30
# 2/2 [==============================] - 7s 6s/step - loss: 2.2995 - accuracy: 0.5625 - precision: 0.4532 - recall: 0.6496 - val_loss: 0.6626 - val_accuracy: 0.6875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/30
# 2/2 [==============================] - 6s 6s/step - loss: 2.2322 - accuracy: 0.6354 - precision: 0.4554 - recall: 0.6768 - val_loss: 0.6598 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/30
# 2/2 [==============================] - 6s 6s/step - loss: 1.8623 - accuracy: 0.6667 - precision: 0.5137 - recall: 0.7576 - val_loss: 0.6559 - val_accuracy: 0.7188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/30
# 2/2 [==============================] - 7s 6s/step - loss: 2.2318 - accuracy: 0.6146 - precision: 0.4989 - recall: 0.7836 - val_loss: 0.6590 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/30
# 2/2 [==============================] - 7s 6s/step - loss: 2.1898 - accuracy: 0.5521 - precision: 0.4150 - recall: 0.6490 - val_loss: 0.6567 - val_accuracy: 0.7188 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/30
# 2/2 [==============================] - 7s 6s/step - loss: 1.9246 - accuracy: 0.6979 - precision: 0.6011 - recall: 0.8222 - val_loss: 0.6604 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/30
# 2/2 [==============================] - 7s 6s/step - loss: 1.9266 - accuracy: 0.6146 - precision: 0.4545 - recall: 0.8841 - val_loss: 0.6611 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/30
# 2/2 [==============================] - 7s 6s/step - loss: 1.5527 - accuracy: 0.6771 - precision: 0.5392 - recall: 0.8007 - val_loss: 0.6647 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/30
# 2/2 [==============================] - 6s 6s/step - loss: 1.6128 - accuracy: 0.7604 - precision: 0.6131 - recall: 0.8492 - val_loss: 0.6685 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/30
# 2/2 [==============================] - 6s 6s/step - loss: 1.1289 - accuracy: 0.8438 - precision: 0.7129 - recall: 1.0000 - val_loss: 0.6732 - val_accuracy: 0.7031 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/30
# 2/2 [==============================] - 7s 6s/step - loss: 1.2052 - accuracy: 0.7708 - precision: 0.5655 - recall: 0.9667 - val_loss: 0.6788 - val_accuracy: 0.6875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/30
# 2/2 [==============================] - 7s 6s/step - loss: 1.6659 - accuracy: 0.7396 - precision: 0.6378 - recall: 0.7952 - val_loss: 0.6845 - val_accuracy: 0.6875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 21/30
# 2/2 [==============================] - 6s 6s/step - loss: 1.2718 - accuracy: 0.7604 - precision: 0.5741 - recall: 1.0000 - val_loss: 0.6906 - val_accuracy: 0.6875 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 22/30
# 2/2 [==============================] - 6s 6s/step - loss: 1.3434 - accuracy: 0.8229 - precision: 0.7333 - recall: 0.8690 - val_loss: 0.6977 - val_accuracy: 0.2969 - val_precision: 0.2969 - val_recall: 1.0000
# Epoch 23/30
# 2/2 [==============================] - 7s 7s/step - loss: 1.1101 - accuracy: 0.8229 - precision: 0.6754 - recall: 1.0000 - val_loss: 0.7041 - val_accuracy: 0.3125 - val_precision: 0.3125 - val_recall: 1.0000
# Epoch 24/30
# 2/2 [==============================] - 7s 6s/step - loss: 1.3640 - accuracy: 0.7604 - precision: 0.5595 - recall: 0.8918 - val_loss: 0.7148 - val_accuracy: 0.2812 - val_precision: 0.2812 - val_recall: 1.0000
# Epoch 25/30
# 2/2 [==============================] - 6s 6s/step - loss: 1.2441 - accuracy: 0.7917 - precision: 0.5656 - recall: 1.0000 - val_loss: 0.7239 - val_accuracy: 0.2969 - val_precision: 0.2969 - val_recall: 1.0000
# Epoch 26/30
# 2/2 [==============================] - 7s 6s/step - loss: 0.9022 - accuracy: 0.8646 - precision: 0.8536 - recall: 0.8346 - val_loss: 0.7336 - val_accuracy: 0.2969 - val_precision: 0.2969 - val_recall: 1.0000
# Epoch 27/30
# 2/2 [==============================] - 6s 6s/step - loss: 1.3863 - accuracy: 0.7396 - precision: 0.6086 - recall: 0.8007 - val_loss: 0.7437 - val_accuracy: 0.2969 - val_precision: 0.2969 - val_recall: 1.0000
# Epoch 28/30
# 2/2 [==============================] - 6s 5s/step - loss: 0.9908 - accuracy: 0.8750 - precision: 0.7350 - recall: 1.0000 - val_loss: 0.7545 - val_accuracy: 0.2969 - val_precision: 0.2969 - val_recall: 1.0000
# Epoch 29/30
# 2/2 [==============================] - 6s 6s/step - loss: 1.1657 - accuracy: 0.8438 - precision: 0.6944 - recall: 1.0000 - val_loss: 0.7624 - val_accuracy: 0.2969 - val_precision: 0.2969 - val_recall: 1.0000
# Epoch 30/30
# 2/2 [==============================] - 7s 6s/step - loss: 1.0637 - accuracy: 0.8125 - precision: 0.6740 - recall: 0.9444 - val_loss: 0.7756 - val_accuracy: 0.2812 - val_precision: 0.2812 - val_recall: 1.0000

# %% [markdown]
# ## Step 7. 결과 확인 및 시각화

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 10))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ## Step 8. 최종 Test dataset 검정하기

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 1/1 [==============================] - 8s 8s/step - loss: 0.7438 - accuracy: 0.3810 - precision: 0.3810 - recall: 1.0000

# %% [markdown]
# ## Discussion
